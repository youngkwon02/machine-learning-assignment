# %% [markdown]
# # K-means clustering

# %% [markdown]
# ## import library

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib import cm

# %% [markdown]
# ## load data

# %%
fname_data = 'assignment_11_data.csv'

feature = np.genfromtxt(fname_data, delimiter=',')

x = feature[:,0]
y = feature[:,1]

number_data     = np.size(feature, 0)
number_feature  = np.size(feature, 1)

print('number of data : {}'.format(number_data))
print('number of feature : {}'.format(number_feature))
# Out:
# number of data : 1000
# number of feature : 2

# %% [markdown]
# ## plot the input data

# %%
plt.figure(figsize=(8,8))   
plt.title('input data')

plt.scatter(x, y, color='blue')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## compute distance
# - feature : $n \times m$, center : $1 \times m$, distance : $n \times 1$
# - $n$ : number of data, $m$ : number of features

# %%
def compute_distance(feature, center):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    distance =(feature - center) ** 2
    distance = distance[:, 0] + distance[:, 1]

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return distance

# %% [markdown]
# ## compute centroid
# - feature : $n \times m$, label_feature : $n \times 1$, value_label : $1 \times 1$, centroid : $1 \times m$
# - $n$ : number of data, $m$ : number of features

# %%
def compute_centroid(feature, label_feature, label):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    centroid = np.zeros(feature.shape[1])
    c = 0
    for i in range(feature.shape[0]):
        if (label_feature[i] == label):
            centroid += feature[i]
            c += 1
    if c != 0:
        centroid /= c
    
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return centroid

# %% [markdown]
# ## compute label
# - distance : $n \times k$, label_feature : $n \times 1$
# - $n$ : number of data, $k$ : number of clusters

# %%
def compute_label(distance):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    label_feature = np.argmin(distance, axis=1)

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    
    return label_feature

# %% [markdown]
# ## the number of clusters $K = 2$

# %%
number_cluster          = 2
number_iteration        = 2000     # you can modify this value
loss_iteration_02       = np.zeros(number_iteration)
centroid_iteration_02   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_02        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#

def compute_loss(feature, label_feature, label_cluster, centroid):
  loss = 0
  for i in range(len(label_cluster)):
    j = np.where(label_feature == i)
    loss += np.sum(compute_distance(feature[j], centroid[i]))
  return loss / label_feature.shape[0]


dist_iteration_02 = np.zeros(shape=(number_data, number_cluster))
cent = np.zeros((number_cluster, number_feature))

for i in range(number_iteration):
  for c in range(number_cluster):
    cent[c] = compute_centroid(feature, label_feature_02, c)
    dist_iteration_02[:, c] = compute_distance(feature, cent[c])
    
  label_feature_02 = compute_label(dist_iteration_02)
  loss_iteration_02[i] = compute_loss(feature, label_feature_02, np.arange(0, number_cluster), cent)
  centroid_iteration_02[i] = cent

#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## the number of clusters $K = 4$

# %%
number_cluster          = 4
number_iteration        = 2000     # you can modify this value
loss_iteration_04       = np.zeros(number_iteration)
centroid_iteration_04   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_04        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#

dist_iteration_04 = np.zeros(shape=(number_data, number_cluster))
cent = np.zeros((number_cluster, number_feature))

for i in range(number_iteration):
  for c in range(number_cluster):
    new_cent = compute_centroid(feature, label_feature_04, c)
    if new_cent[0] != 0:
      cent[c] = new_cent
    dist_iteration_04[:, c] = compute_distance(feature, cent[c])
    
  label_feature_04 = compute_label(dist_iteration_04)
  loss_iteration_04[i] = compute_loss(feature, label_feature_04, np.arange(0, number_cluster), cent)
  centroid_iteration_04[i] = cent

#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## the number of clusters $K = 8$

# %%
number_cluster          = 8
number_iteration        = 2000     # you can modify this value
loss_iteration_08       = np.zeros(number_iteration)
centroid_iteration_08   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_08        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#

dist_iteration_08 = np.zeros(shape=(number_data, number_cluster))
cent = np.zeros((number_cluster, number_feature))

for i in range(number_iteration):
  for c in range(number_cluster):
    new_cent = compute_centroid(feature, label_feature_08, c)
    if new_cent[0] != 0:
      cent[c] = new_cent
    dist_iteration_08[:, c] = compute_distance(feature, cent[c])
    
  label_feature_08 = compute_label(dist_iteration_08)
  loss_iteration_08[i] = compute_loss(feature, label_feature_08, np.arange(0, number_cluster), cent)
  centroid_iteration_08[i] = cent

#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## the number of clusters $K = 16$

# %%
number_cluster          = 16
number_iteration        = 3000     # you can modify this value
loss_iteration_16       = np.zeros(number_iteration)
centroid_iteration_16   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_16        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#

dist_iteration_16 = np.zeros(shape=(number_data, number_cluster))
cent = np.zeros((number_cluster, number_feature))

for i in range(number_iteration):
  for c in range(number_cluster):
    new_cent = compute_centroid(feature, label_feature_16, c)
    if new_cent[0] != 0:
      cent[c] = new_cent
    dist_iteration_16[:, c] = compute_distance(feature, cent[c])
    
  label_feature_16 = compute_label(dist_iteration_16)
  loss_iteration_16[i] = compute_loss(feature, label_feature_16, np.arange(0, number_cluster), cent)
  centroid_iteration_16[i] = cent

#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## functions for presenting the results

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
def function_result_01():

    print("final loss (K=2) = {:13.10f}".format(loss_iteration_02[-1]))

# %%
def function_result_02():

    print("final loss (K=4) = {:13.10f}".format(loss_iteration_04[-1]))

# %%
def function_result_03():

    print("final loss (K=8) = {:13.10f}".format(loss_iteration_08[-1]))

# %%
def function_result_04():

    print("final loss (K=16) = {:13.10f}".format(loss_iteration_16[-1]))

# %%
def function_result_05():
    
    plt.figure(figsize=(8,6)) 
    plt.title('loss (K=2)')

    plt.plot(loss_iteration_02, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_06():
    
    plt.figure(figsize=(8,6)) 
    plt.title('loss (K=4)')

    plt.plot(loss_iteration_04, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_07():
    
    plt.figure(figsize=(8,6))
    plt.title('loss (K=8)')

    plt.plot(loss_iteration_08, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_08():
    
    plt.figure(figsize=(8,6))
    plt.title('loss (K=16)')

    plt.plot(loss_iteration_16, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_09():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=2)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    color_code= ['green', 'orange']

    for i in range(centroid_iteration_02.shape[1]):
        _label = "cluster=" + str(i)
        plt.plot(centroid_iteration_02[:, i, 0], centroid_iteration_02[:, i, 1], '-', color=color_code[i], label=_label)
        
    plt.plot(centroid_iteration_02[0, :, 0], centroid_iteration_02[0, :, 1], 'o', color='blue', label='initial')    
    plt.plot(centroid_iteration_02[len(centroid_iteration_02) - 1, : , 0], centroid_iteration_02[len(centroid_iteration_02) - 1, : , 1], 's', color='red', label='final')
    
    plt.legend(loc='upper left')
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_10():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=4)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    color_code= ['blue', 'orange', 'green', 'red']

    for i in range(centroid_iteration_04.shape[1]):
        _label = "cluster=" + str(i)
        plt.plot(centroid_iteration_04[:, i, 0], centroid_iteration_04[:, i, 1], '-', color=color_code[i], label=_label)
        
    plt.plot(centroid_iteration_04[0, :, 0], centroid_iteration_04[0, :, 1], 'o', color='blue', label='initial')    
    plt.plot(centroid_iteration_04[len(centroid_iteration_04) - 1, : , 0], centroid_iteration_04[len(centroid_iteration_04) - 1, : , 1], 's', color='red', label='final')
    
    plt.legend(loc='upper left')
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_11():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=8)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    color_code= ['blue', 'orange', 'green', 'red', 'purple', 'magenta', 'pink', 'cyan']

    for i in range(centroid_iteration_08.shape[1]):
        _label = "cluster=" + str(i)
        plt.plot(centroid_iteration_08[:, i, 0], centroid_iteration_08[:, i, 1], '-', color=color_code[i], label=_label)
        
    plt.plot(centroid_iteration_08[0, :, 0], centroid_iteration_08[0, :, 1], 'o', color='blue', label='initial')    
    plt.plot(centroid_iteration_08[len(centroid_iteration_08) - 1, : , 0], centroid_iteration_08[len(centroid_iteration_08) - 1, : , 1], 's', color='red', label='final')
    
    plt.legend(loc='upper left')
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_12():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=16)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    color_code= ['#65a0cb', '#fe9d4a', '#61b861', '#e56f6f', '#ae8bcd', '#ab847b', '#eca7d7', '#9f9f9f', '#cccd58', '#4fcdda', '#5697c6', '#ffa55a', '#6dbc6b', '#e05b5d', '#ae8bcd', '#aa827a']

    for i in range(centroid_iteration_16.shape[1]):
        _label = "cluster=" + str(i)
        plt.plot(centroid_iteration_16[:, i, 0], centroid_iteration_16[:, i, 1], '-', color=color_code[i], label=_label)
        
    plt.plot(centroid_iteration_16[0, :, 0], centroid_iteration_16[0, :, 1], 'o', color='blue', label='initial')    
    plt.plot(centroid_iteration_16[len(centroid_iteration_16) - 1, : , 0], centroid_iteration_16[len(centroid_iteration_16) - 1, : , 1], 's', color='red', label='final')
    
    plt.legend(loc='upper left')
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_13():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=2)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    feature_x = feature[:, 0]
    feature_y = feature[:, 1]

    t = plt.scatter(feature_x, feature_y, c=label_feature_02, cmap=plt.cm.get_cmap('seismic', len(label_feature_02)))
    plt.colorbar(t, ticks=np.linspace(0, 9, 10))
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_14():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=4)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    feature_x = feature[:, 0]
    feature_y = feature[:, 1]

    t = plt.scatter(feature_x, feature_y, c=label_feature_04, cmap=plt.cm.get_cmap('seismic', len(label_feature_04)))
    plt.colorbar(t, ticks=np.linspace(0, 3, 4))
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_15():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=8)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    feature_x = feature[:, 0]
    feature_y = feature[:, 1]

    t = plt.scatter(feature_x, feature_y, c=label_feature_08, cmap=plt.cm.get_cmap('Spectral', len(label_feature_08)))
    plt.colorbar(t, ticks=np.linspace(0, 7, 8))
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_16():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=16)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    feature_x = feature[:, 0]
    feature_y = feature[:, 1]

    t = plt.scatter(feature_x, feature_y, c=label_feature_16, cmap=plt.cm.get_cmap('rainbow', len(label_feature_16)))
    plt.colorbar(t, ticks=np.linspace(-1, 16, 18))
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## results

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
number_result = 16

for i in range(number_result):
    title = '## [RESULT {:02d}]'.format(i+1)
    name_function = 'function_result_{:02d}()'.format(i+1)

    print('**************************************************')
    print(title)
    print('**************************************************')
    eval(name_function)
# Out:
# **************************************************
# ## [RESULT 01]
# **************************************************
# final loss (K=2) = 31.1123356206
# **************************************************
# ## [RESULT 02]
# **************************************************
# final loss (K=4) = 10.5831291650
# **************************************************
# ## [RESULT 03]
# **************************************************
# final loss (K=8) =  5.6813500213
# **************************************************
# ## [RESULT 04]
# **************************************************
# final loss (K=16) =  3.0656203367
# **************************************************
# ## [RESULT 05]
# **************************************************
# **************************************************
# ## [RESULT 06]
# **************************************************
# **************************************************
# ## [RESULT 07]
# ...
